# %% [markdown]
# ## Langchain - Part 1

# %%
import langchain
import os
from langchain_google_genai import ChatGoogleGenerativeAI 
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
load_dotenv(dotenv_path=".env", override=True)
google_api_key = os.getenv("GOOGLE_API_KEY")

# %%
print(google_api_key)
# Out:
# AIzaSyBMHT6RYFEUWJ1_Uy7TQ5ePY61knAAvfW4

# %%
google_llm = ChatGoogleGenerativeAI(temperature=0,model="gemini-2.0-flash-lite",google_api_key=google_api_key)

# %%
ollama_llm = ChatOllama(
    temperature=0,
    model="phi3:mini"  # or any model you have in ollama
)

# %%
prompt = PromptTemplate(input_variables=["input"],
                        template="you are a helpful person with funny . complete the user request {input}")

# %%
chain = prompt | ollama_llm

# %%
res = chain.invoke({"input":"what is mean by computer"})
print(res.content)
# Out:
# A computer is like a magical box that can do math, write stories, and even play hide and seek with information! It's like having a tiny robot that can help you with your homework, watch funny videos, and play your favorite games. But remember, just like with any magic, you have to treat it with care and respect!
